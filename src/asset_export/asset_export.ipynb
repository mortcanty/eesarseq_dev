# %% [markdown]
# # Deforestation detection in the Ecuadorian rainforest

# %% [markdown]
# This code serves to classify pixel-level change on individually owned Socio Bosque plots in Ecuador using Sentinel SAR-1 radar satellite data. Good data coverage exists between 2017 and now, therefore we will focus on 2017-2022. The change classification follows Mort Canty's tutorial on the GEE guides: https://developers.google.com/earth-engine/tutorials/community/detecting-changes-in-sentinel-1-imagery-pt-3 .

# %% [markdown]
# ## Setup

# %%
import ee
#ee.Authenticate()
ee.Initialize()

# %%
# adding some additional packages for stats and data wrangling
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, gamma, f, chi2
import IPython.display as disp
# %matplotlib inline

# %% [markdown]
# ## Shapefiles

# %% [markdown]
# Shapefiles come from here: http://ide.ambiente.gob.ec/mapainteractivo/ They are reduced to 20% complexity with mapshaper.org and filtered for individual land plots only using QGIS. The idea in the end is to do this for all 2500 shapefiles. This is a test, therefore we will use the first two plots as an example.

# %%
# !pip install geemap
# Out:
# Collecting geemap
#   Downloading geemap-0.20.1-py2.py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.0 MB/s eta 0:00:0000:0100:01
# Collecting folium>=0.11.0
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 7.8 MB/s eta 0:00:00
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (3.7.0)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting eerepr>=0.0.4
#   Downloading eerepr-0.0.4-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: pillow in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (9.4.0)
# Collecting python-box
#   Downloading python_box-7.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.4 MB/s eta 0:00:0000:0100:01
# Collecting scooby
#   Downloading scooby-0.7.1-py3-none-any.whl (16 kB)
# Collecting geeadd>=0.5.1
#   Downloading geeadd-0.5.6-py3-none-any.whl (30 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 9.0 MB/s eta 0:00:00
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sankee>=0.1.0
#   Downloading sankee-0.2.1.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipytree in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (0.2.2)
# Collecting ipywidgets<8.0.0
#   Downloading ipywidgets-7.7.3-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: ipyleaflet>=0.17.0 in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (0.17.2)
# Requirement already satisfied: numpy in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (1.24.2)
# Requirement already satisfied: xyzservices in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (2023.2.0)
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gdown
#   Downloading gdown-4.6.4-py3-none-any.whl (14 kB)
# Collecting ee-extra>=0.0.10
#   Downloading ee_extra-0.0.15.tar.gz (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: earthengine-api>=0.1.304 in /home/mort/venv310/lib/python3.10/site-packages (from geemap) (0.1.342)
# Collecting geojson
#   Downloading geojson-3.0.1-py3-none-any.whl (15 kB)
# Collecting bqplot
#   Downloading bqplot-0.12.36-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.3 MB/s eta 0:00:0000:0100:01
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-2.2.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 10.8 MB/s eta 0:00:00
# Collecting pandas
#   Using cached pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# Collecting pyshp>=2.1.3
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /home/mort/venv310/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (0.21.0)
# Requirement already satisfied: google-auth>=1.4.1 in /home/mort/venv310/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.16.1)
# Requirement already satisfied: requests in /home/mort/venv310/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.28.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /home/mort/venv310/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.79.0)
# Requirement already satisfied: google-cloud-storage in /home/mort/venv310/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (2.7.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/mort/venv310/lib/python3.10/site-packages (from earthengine-api>=0.1.304->geemap) (0.1.0)
# Requirement already satisfied: jinja2>=2.9 in /home/mort/venv310/lib/python3.10/site-packages (from folium>=0.11.0->geemap) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in /home/mort/venv310/lib/python3.10/site-packages (from folium>=0.11.0->geemap) (0.6.0)
# Collecting logzero>=1.5.0
#   Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /home/mort/venv310/lib/python3.10/site-packages (from geeadd>=0.5.1->geemap) (4.11.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/mort/venv310/lib/python3.10/site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.2-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.7/245.7 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/mort/venv310/lib/python3.10/site-packages (from ipywidgets<8.0.0->geemap) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/mort/venv310/lib/python3.10/site-packages (from ipywidgets<8.0.0->geemap) (5.9.0)
# Requirement already satisfied: ipython>=4.0.0 in /home/mort/venv310/lib/python3.10/site-packages (from ipywidgets<8.0.0->geemap) (8.10.0)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipykernel>=4.5.1 in /home/mort/venv310/lib/python3.10/site-packages (from ipywidgets<8.0.0->geemap) (6.21.2)
# Collecting plotly>=5.2.2
#   Downloading plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 11.2 MB/s eta 0:00:0000:0100:01
# Collecting whitebox
#   Downloading whitebox-2.2.0-py2.py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /home/mort/venv310/lib/python3.10/site-packages (from pandas->geemap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mort/venv310/lib/python3.10/site-packages (from pandas->geemap) (2.8.2)
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 11.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /home/mort/venv310/lib/python3.10/site-packages (from gdown->geemap) (1.16.0)
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.8 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mort/venv310/lib/python3.10/site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/mort/venv310/lib/python3.10/site-packages (from matplotlib->geemap) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mort/venv310/lib/python3.10/site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mort/venv310/lib/python3.10/site-packages (from matplotlib->geemap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/mort/venv310/lib/python3.10/site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mort/venv310/lib/python3.10/site-packages (from matplotlib->geemap) (4.38.0)
# Requirement already satisfied: soupsieve>1.2 in /home/mort/venv310/lib/python3.10/site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/mort/venv310/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/mort/venv310/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (2.11.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/mort/venv310/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/mort/venv310/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/mort/venv310/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.9)
# Requirement already satisfied: tornado>=6.1 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (6.2)
# Requirement already satisfied: psutil in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (5.9.4)
# Requirement already satisfied: comm>=0.1.1 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (0.1.2)
# Requirement already satisfied: pyzmq>=20 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (25.0.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (1.6.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (5.2.0)
# Requirement already satisfied: nest-asyncio in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/mort/venv310/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (8.0.3)
# Requirement already satisfied: backcall in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (2.14.0)
# Requirement already satisfied: pickleshare in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.18.2)
# Requirement already satisfied: decorator in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (5.1.1)
# Requirement already satisfied: stack-data in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.6.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/mort/venv310/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (3.0.37)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mort/venv310/lib/python3.10/site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.1.2)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mort/venv310/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/mort/venv310/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mort/venv310/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mort/venv310/lib/python3.10/site-packages (from requests->earthengine-api>=0.1.304->geemap) (1.26.14)
# Requirement already satisfied: notebook>=4.4.1 in /home/mort/venv310/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (6.5.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /home/mort/venv310/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.4.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /home/mort/venv310/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.2)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /home/mort/venv310/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (3.19.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/mort/venv310/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (1.58.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/mort/venv310/lib/python3.10/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/mort/venv310/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (3.0.0)
# Requirement already satisfied: nbformat in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (5.7.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.16.0)
# Requirement already satisfied: argon2-cffi in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (21.3.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.5.2)
# Requirement already satisfied: nbconvert>=5 in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (7.2.9)
# Requirement already satisfied: terminado>=0.8.3 in /home/mort/venv310/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mort/venv310/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mort/venv310/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/mort/venv310/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mort/venv310/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (2.2.1)
# Requirement already satisfied: pure-eval in /home/mort/venv310/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/mort/venv310/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (1.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /home/mort/venv310/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.3.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/mort/venv310/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.7.2)
# Requirement already satisfied: bleach in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (6.0.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.0.5)
# Requirement already satisfied: jupyterlab-pygments in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.2.2)
# Requirement already satisfied: defusedxml in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.7.1)
# Requirement already satisfied: tinycss2 in /home/mort/venv310/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.2.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/mort/venv310/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (4.17.3)
# Requirement already satisfied: fastjsonschema in /home/mort/venv310/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.16.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/mort/venv310/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (22.2.0)
# Requirement already satisfied: websocket-client in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (3.6.2)
# Requirement already satisfied: jupyter-server-terminals in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.4.0 in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.6.3)
# Requirement already satisfied: cffi>=1.0.1 in /home/mort/venv310/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.15.1)
# Requirement already satisfied: webencodings in /home/mort/venv310/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /home/mort/venv310/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.3.0)
# Requirement already satisfied: pycparser in /home/mort/venv310/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.21)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (6.0)
# Requirement already satisfied: rfc3339-validator in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/mort/venv310/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.0.7)
# Requirement already satisfied: fqdn in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.5.1)
# Requirement already satisfied: isoduration in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (20.11.0)
# Requirement already satisfied: uri-template in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.12)
# Requirement already satisfied: jsonpointer>1.13 in /home/mort/venv310/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.3)
# Requirement already satisfied: arrow>=0.15.0 in /home/mort/venv310/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.2.3)
# Building wheels for collected packages: ee-extra, sankee, pycrs, pyperclip, future
#   Building wheel for ee-extra (setup.py) ... done
#   Created wheel for ee-extra: filename=ee_extra-0.0.15-py3-none-any.whl size=236772 sha256=50ca767c289fafa256005f9bcf0ddbb7ca62b26c36cb6937357ca974a24d1119
#   Stored in directory: /home/mort/.cache/pip/wheels/29/96/0e/4e36b0dfd85e16867723df739294c0aa45a65b191adac4d959
#   Building wheel for sankee (setup.py) ... done
#   Created wheel for sankee: filename=sankee-0.2.1-py3-none-any.whl size=29341 sha256=05bc8635d86115d2d7a13dd5042afed72840b4d628e4b8c3c180e8098211ec6c
#   Stored in directory: /home/mort/.cache/pip/wheels/6b/e1/38/521d97f1296805b9d658157c9d3117c3a7133c2e7e9c822959
#   Building wheel for pycrs (setup.py) ... done
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32704 sha256=f96e9fa0b0313f2a2ad4ab5a8f6703023b82ae555d9d939f57be36293620d6f6
#   Stored in directory: /home/mort/.cache/pip/wheels/47/1d/70/7a5bdf33347e7c75e95b06b1fa38f076a59a9506653cc24aff
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=751548c6ab898b3dbd15985892bb72b8fadf8b4729e8e7189f092d8729e377e5
#   Stored in directory: /home/mort/.cache/pip/wheels/04/24/fe/140a94a7f1036003ede94579e6b4227fe96c840c6f4dcbe307
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492037 sha256=2c6eace4c1ceb66d638ec3dca06abe808d7b966f0fdef518a125159ae2d70cf5
#   Stored in directory: /home/mort/.cache/pip/wheels/5e/a9/47/f118e66afd12240e4662752cc22cefae5d97275623aa8ef57d
# Successfully built ee-extra sankee pycrs pyperclip future
# Installing collected packages: pyperclip, pycrs, logzero, colour, tqdm, tenacity, scooby, ratelim, python-box, PySocks, pyshp, jupyterlab-widgets, geojson, future, filelock, click, whitebox, plotly, pandas, geocoder, ffmpeg-python, gdown, folium, geeadd, eerepr, ee-extra, widgetsnbextension, ipywidgets, sankee, ipyfilechooser, ipyevents, bqplot, whiteboxgui, geemap
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.5
#     Uninstalling jupyterlab-widgets-3.0.5:
#       Successfully uninstalled jupyterlab-widgets-3.0.5
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.5
#     Uninstalling widgetsnbextension-4.0.5:
#       Successfully uninstalled widgetsnbextension-4.0.5
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.4
#     Uninstalling ipywidgets-8.0.4:
#       Successfully uninstalled ipywidgets-8.0.4
# Successfully installed PySocks-1.7.1 bqplot-0.12.36 click-8.1.3 colour-0.1.5 ee-extra-0.0.15 eerepr-0.0.4 ffmpeg-python-0.2.0 filelock-3.9.0 folium-0.14.0 future-0.18.3 gdown-4.6.4 geeadd-0.5.6 geemap-0.20.1 geocoder-1.38.1 geojson-3.0.1 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipywidgets-7.7.3 jupyterlab-widgets-1.1.2 logzero-1.7.0 pandas-1.5.3 plotly-5.13.1 pycrs-1.0.2 pyperclip-1.8.2 pyshp-2.3.1 python-box-7.0.1 ratelim-0.1.6 sankee-0.2.1 scooby-0.7.1 tenacity-8.2.2 tqdm-4.65.0 whitebox-2.2.0 whiteboxgui-2.2.0 widgetsnbextension-3.6.2

# %%
# package to ingest shapefiles
import geemap

# import of shapefiles
plots = geemap.shp_to_ee('shapefiles/socio_bosque_simple_indiv_gcs.shp', encoding = "latin-1")

# %%
plot_list = ee.FeatureCollection.toList(plots,2)

# %%
print(plot_list.length().getInfo())
# Out:
# 2

# %% [markdown]
# ## Functions and helper objects

# %%
# helper lists
start_list = ee.List(['2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01'])
end_list = ee.List(['2018-01-01', '2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01', '2023-01-01'])
year_list = ee.List.sequence(0,5)
month_list = ee.List.sequence(1,12)

# %%
# Functions copied from Mort Canty's tutorial
def det(im):
    return im.expression('b(0) * b(1)')

def chi2cdf(chi2, df):
    return ee.Image(chi2.divide(2)).gammainc(ee.Number(df).divide(2))

def log_det_sum(im_list, j):
    """Returns log of determinant of the sum of the first j images in im_list."""
    im_ist = ee.List(im_list)
    sumj = ee.ImageCollection(im_list.slice(0, j)).reduce(ee.Reducer.sum())
    return ee.Image(det(sumj)).log()

def log_det(im_list, j):
    """Returns log of the determinant of the jth image in im_list."""
    im = ee.Image(ee.List(im_list).get(j.subtract(1)))
    return ee.Image(det(im)).log()

def pval(im_list, j, m=4.4):
    """Calculates -2logRj for im_list and returns P value and -2logRj."""
    im_list = ee.List(im_list)
    j = ee.Number(j)
    m2logRj = (log_det_sum(im_list, j.subtract(1))
               .multiply(j.subtract(1))
               .add(log_det(im_list, j))
               .add(ee.Number(2).multiply(j).multiply(j.log()))
               .subtract(ee.Number(2).multiply(j.subtract(1))
               .multiply(j.subtract(1).log()))
               .subtract(log_det_sum(im_list,j).multiply(j))
               .multiply(-2).multiply(m))
    pv = ee.Image.constant(1).subtract(chi2cdf(m2logRj, 2))
    return (pv, m2logRj)

def p_values(im_list):
    """Pre-calculates the P-value array for a list of images."""
    im_list = ee.List(im_list)
    k = im_list.length()

    def ells_map(ell):
        """Arranges calculation of pval for combinations of k and j."""
        ell = ee.Number(ell)
        # Slice the series from k-l+1 to k (image indices start from 0).
        im_list_ell = im_list.slice(k.subtract(ell), k)

        def js_map(j):
            """Applies pval calculation for combinations of k and j."""
            j = ee.Number(j)
            pv1, m2logRj1 = pval(im_list_ell, j)
            return ee.Feature(None, {'pv': pv1, 'm2logRj': m2logRj1})

        # Map over j=2,3,...,l.
        js = ee.List.sequence(2, ell)
        pv_m2logRj = ee.FeatureCollection(js.map(js_map))

        # Calculate m2logQl from collection of m2logRj images.
        m2logQl = ee.ImageCollection(pv_m2logRj.aggregate_array('m2logRj')).sum()
        pvQl = ee.Image.constant(1).subtract(chi2cdf(m2logQl, ell.subtract(1).multiply(2)))
        pvs = ee.List(pv_m2logRj.aggregate_array('pv')).add(pvQl)
        return pvs

    # Map over l = k to 2.
    ells = ee.List.sequence(k, 2, -1)
    pv_arr = ells.map(ells_map)

    # Return the P value array ell = k,...,2, j = 2,...,l.
    return pv_arr

def filter_j(current, prev):
    """Calculates change maps; iterates over j indices of pv_arr."""
    pv = ee.Image(current)
    prev = ee.Dictionary(prev)
    pvQ = ee.Image(prev.get('pvQ'))
    i = ee.Number(prev.get('i'))
    cmap = ee.Image(prev.get('cmap'))
    smap = ee.Image(prev.get('smap'))
    fmap = ee.Image(prev.get('fmap'))
    bmap = ee.Image(prev.get('bmap'))
    alpha = ee.Image(prev.get('alpha'))
    j = ee.Number(prev.get('j'))
    cmapj = cmap.multiply(0).add(i.add(j).subtract(1))
    # Check      Rj?            Ql?                  Row i?
    tst = pv.lt(alpha).And(pvQ.lt(alpha)).And(cmap.eq(i.subtract(1)))
    # Then update cmap...
    cmap = cmap.where(tst, cmapj)
    # ...and fmap...
    fmap = fmap.where(tst, fmap.add(1))
    # ...and smap only if in first row.
    smap = ee.Algorithms.If(i.eq(1), smap.where(tst, cmapj), smap)
    # Create bmap band and add it to bmap image.
    idx = i.add(j).subtract(2)
    tmp = bmap.select(idx)
    bname = bmap.bandNames().get(idx)
    tmp = tmp.where(tst, 1)
    tmp = tmp.rename([bname])
    bmap = bmap.addBands(tmp, [bname], True)
    return ee.Dictionary({'i': i, 'j': j.add(1), 'alpha': alpha, 'pvQ': pvQ,
                          'cmap': cmap, 'smap': smap, 'fmap': fmap, 'bmap':bmap})

def filter_i(current, prev):
    """Arranges calculation of change maps; iterates over row-indices of pv_arr."""
    current = ee.List(current)
    pvs = current.slice(0, -1 )
    pvQ = ee.Image(current.get(-1))
    prev = ee.Dictionary(prev)
    i = ee.Number(prev.get('i'))
    alpha = ee.Image(prev.get('alpha'))
    median = prev.get('median')
    # Filter Ql p value if desired.
    pvQ = ee.Algorithms.If(median, pvQ.focalMedian(2.5), pvQ)
    cmap = prev.get('cmap')
    smap = prev.get('smap')
    fmap = prev.get('fmap')
    bmap = prev.get('bmap')
    first = ee.Dictionary({'i': i, 'j': 1, 'alpha': alpha ,'pvQ': pvQ,
                           'cmap': cmap, 'smap': smap, 'fmap': fmap, 'bmap': bmap})
    result = ee.Dictionary(ee.List(pvs).iterate(filter_j, first))
    return ee.Dictionary({'i': i.add(1), 'alpha': alpha, 'median': median,
                          'cmap': result.get('cmap'), 'smap': result.get('smap'),
                          'fmap': result.get('fmap'), 'bmap': result.get('bmap')})

def dmap_iter(current, prev):
    """Reclassifies values in directional change maps."""
    prev = ee.Dictionary(prev)
    j = ee.Number(prev.get('j'))
    image = ee.Image(current)
    avimg = ee.Image(prev.get('avimg'))
    diff = image.subtract(avimg)
    # Get positive/negative definiteness.
    posd = ee.Image(diff.select(0).gt(0).And(det(diff).gt(0)))
    negd = ee.Image(diff.select(0).lt(0).And(det(diff).gt(0)))
    bmap = ee.Image(prev.get('bmap'))
    bmapj = bmap.select(j)
    dmap = ee.Image.constant(ee.List.sequence(1, 3))
    bmapj = bmapj.where(bmapj, dmap.select(2))
    bmapj = bmapj.where(bmapj.And(posd), dmap.select(0))
    bmapj = bmapj.where(bmapj.And(negd), dmap.select(1))
    bmap = bmap.addBands(bmapj, overwrite=True)
    # Update avimg with provisional means.
    i = ee.Image(prev.get('i')).add(1)
    avimg = avimg.add(image.subtract(avimg).divide(i))
    # Reset avimg to current image and set i=1 if change occurred.
    avimg = avimg.where(bmapj, image)
    i = i.where(bmapj, 1)
    return ee.Dictionary({'avimg': avimg, 'bmap': bmap, 'j': j.add(1), 'i': i})

def change_maps(im_list, median=False, alpha=0.05):
    """Calculates thematic change maps."""
    k = im_list.length()
    # Pre-calculate the P value array.
    pv_arr = ee.List(p_values(im_list))
    # Filter P values for change maps.
    cmap = ee.Image(im_list.get(0)).select(0).multiply(0)
    bmap = ee.Image.constant(ee.List.repeat(0,k.subtract(1))).add(cmap)
    alpha = ee.Image.constant(alpha)
    first = ee.Dictionary({'i': 1, 'alpha': alpha, 'median': median,
                           'cmap': cmap, 'smap': cmap, 'fmap': cmap, 'bmap': bmap})
    result = ee.Dictionary(pv_arr.iterate(filter_i, first))
    # Post-process bmap for change direction.
    bmap =  ee.Image(result.get('bmap'))
    avimg = ee.Image(im_list.get(0))
    j = ee.Number(0)
    i = ee.Image.constant(1)
    first = ee.Dictionary({'avimg': avimg, 'bmap': bmap, 'j': j, 'i': i})
    dmap = ee.Dictionary(im_list.slice(1).iterate(dmap_iter, first)).get('bmap')
    return ee.Dictionary(result.set('bmap', dmap))

# %%
# Function that, when mapped over multiple plots, generates an image collection asset with change maps for each plot:
def generate_collection(plot):
    
    # Extract geometry and plot id
    plot = ee.Feature(plot)
    roi = plot.geometry()
    plot_id = plot.get('codigo_con')
    
    # Select the first image that covers the plot, the timerange, and both polarizations
    orbit_det = ee.Image(ee.ImageCollection('COPERNICUS/S1_GRD')
                         .filterBounds(roi)
                         .filterDate(ee.Date('2017-01-01'), ee.Date('2022-12-31'))
                         .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH'))
                         .first())

    # Extract node
    orbit_node = orbit_det.get('orbitProperties_pass')
    # Extract relative orbit number
    orbit_num = orbit_det.get('relativeOrbitNumber_start')
    
    # Build relevant Image Collection
    s1_coll = (ee.ImageCollection('COPERNICUS/S1_GRD')
               .filterBounds(roi)
               .filterDate(ee.Date('2017-01-01'), ee.Date('2022-12-31'))
               .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH'))
               .filter(ee.Filter.eq('orbitProperties_pass', orbit_node))
               .filter(ee.Filter.eq('relativeOrbitNumber_start', orbit_num))
               .map(lambda img: img.set('date', ee.Date(img.date()).format('YYYYMMdd')))
               .sort('date')
               .map(lambda img: img.clip(roi)))
    
    # function to create a list of yearly image collections
    def list_of_yearly_coll(year):
        return s1_coll.filterDate(start_list.get(year), end_list.get(year))
    
    list_yr_coll = year_list.map(list_of_yearly_coll)

    # function to extract the first image of every month from a yearly image collection
    def monthly_ts(year):
        yearly_coll = ee.ImageCollection(list_yr_coll.get(year))
        return month_list.map(lambda m: yearly_coll.filter(ee.Filter.calendarRange(m,m,'month')).first())
    
    # Create monthly time series over all six years
    ts = year_list.map(monthly_ts).flatten()
    
    # Create image collection
    ts_coll = ee.ImageCollection.fromImages(ts)
    
    # Create list of images to analyze (back and forth conversion eliminates NAs)
    ts_list = ts_coll.toList(ts_coll.size()) 
    
    # Generate timestamps
    timestamplist = (ee.List((ts_coll.aggregate_array('date').map(lambda d: ee.String('T').cat(ee.String(d)))))
                     .splice(start = 0, count = 1))
    
    # Run algorithm at 5% significance
    result = ee.Dictionary(change_maps(ts_list, median=True, alpha=0.05))
    
    # Extract the bmap image, add plot id and rename bands
    bmap = ee.Image(result.get('bmap')).set('plot_id', plot_id).rename(timestamplist)
    
    # Export the generated image
    assetexport = ee.batch.Export.image.toAsset(bmap,
                                                description='assetExportTask',
                                                pyramidingPolicy={".default":'sample'},
                                                # this is an image collection:
                                                assetId='projects/ee-mortcanty/assets/kamal1', 
                                                scale=10, maxPixels=1e9)
    return assetexport.start()

# %%
generate_collection(plot_list.get(0))

# %% [markdown]
# ## Output

# %%
plot_list.map(generate_collection)
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_list.map(generate_collection)
#
# File ~/venv310/lib/python3.10/site-packages/ee/apifunction.py:205, in ApiFunction.importApi.<locals>.MakeBoundFunction.<locals>.<lambda>(*args, **kwargs)
#     203 def MakeBoundFunction(func):
#     204   # We need the lambda to capture "func" from the enclosing scope.
# --> 205   return lambda *args, **kwargs: func.call(*args, **kwargs)
#
# File ~/venv310/lib/python3.10/site-packages/ee/function.py:67, in Function.call(self, *args, **kwargs)
#      55 def call(self, *args, **kwargs):
#      56   """Calls the function with the given positional and keyword arguments.
#      57
#      58   Args:
#    (...)
#      65     to that type.
#      66   """
# ---> 67   return self.apply(self.nameArgs(args, kwargs))
#
# File ~/venv310/lib/python3.10/site-packages/ee/function.py:80, in Function.apply(self, named_args)
#      69 def apply(self, named_args):
#      70   """Calls the function with a dictionary of named arguments.
#      71
#      72   Args:
#    (...)
#      78     to that type.
#      79   """
# ---> 80   result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      81   return Function._promoter(result, self.getReturnType())
#
# File ~/venv310/lib/python3.10/site-packages/ee/function.py:107, in Function.promoteArgs(self, args)
#     105 name = spec['name']
#     106 if name in args:
# --> 107   promoted_args[name] = Function._promoter(args[name], spec['type'])
#     108 elif not spec.get('optional'):
#     109   raise ee_exception.EEException(
#     110       'Required argument (%s) missing to function: %s'
#     111       % (name, self.name))
#
# File ~/venv310/lib/python3.10/site-packages/ee/__init__.py:257, in _Promote(arg, klass)
#     254 elif callable(arg):
#     255   # A native function that needs to be wrapped.
#     256   args_count = len(inspect.getfullargspec(arg).args)
# --> 257   return CustomFunction.create(arg, 'Object', ['Object'] * args_count)
#     258 elif isinstance(arg, Encodable):
#     259   # An ee.Function or a computed function like the return value of
#     260   # Image.parseExpression().
#     261   return arg
#
# File ~/venv310/lib/python3.10/site-packages/ee/customfunction.py:124, in CustomFunction.create(func, return_type, arg_types)
#     118 args = [{'name': None, 'type': StringifyType(i)} for i in arg_types]
#     119 signature = {
#     120     'name': '',
#     121     'returns': StringifyType(return_type),
#     122     'args': args
#     123 }
# --> 124 return CustomFunction(signature, func)
#
# File ~/venv310/lib/python3.10/site-packages/ee/customfunction.py:42, in CustomFunction.__init__(self, signature, body)
#      28 """Creates a function defined by a given expression with unbound variables.
#      29
#      30 The expression is created by evaluating the given function
#    (...)
#      37   body: The Python function to evaluate.
#      38 """
#      39 variables = [CustomFunction.variable(arg['type'], arg['name'])
#      40              for arg in signature['args']]
# ---> 42 if body(*variables) is None:
#      43   raise ee_exception.EEException('User-defined methods must return a value')
#      45 # The signature of the function.
#
# Cell In[14], line 69, in generate_collection(plot)
#      62 # Export the generated image
#      63 assetexport = ee.batch.Export.image.toAsset(bmap,
#      64                                             description='assetExportTask',
#      65                                             pyramidingPolicy={".default":'sample'},
#      66                                             # this is an image collection:
#      67                                             assetId='users/peterkamal/change_detection',
#      68                                             scale=10, maxPixels=1e9)
# ---> 69 return assetexport.start()
#
# File ~/venv310/lib/python3.10/site-packages/ee/batch.py:90, in Task.start(self)
#      87   self.config['workloadTag'] = self.workload_tag
#      89 if self.task_type == Task.Type.EXPORT_IMAGE:
# ---> 90   result = data.exportImage(self._request_id, self.config)
#      91 elif self.task_type == Task.Type.EXPORT_MAP:
#      92   result = data.exportMap(self._request_id, self.config)
#
# File ~/venv310/lib/python3.10/site-packages/ee/data.py:1479, in exportImage(request_id, params)
#    1458 """Starts an image export task running.
#    1459
#    1460 This is a low-level method. The higher-level ee.batch.Export.image object
#    (...)
#    1476   If you are using the cloud API, this will be an Operation.
#    1477 """
#    1478 params = params.copy()
# -> 1479 return _prepare_and_run_export(
#    1480     request_id, params,
#    1481     _get_cloud_api_resource().projects().image().export)
#
# File ~/venv310/lib/python3.10/site-packages/ee/data.py:1591, in _prepare_and_run_export(request_id, params, export_endpoint)
#    1589     raise ValueError('"requestId" must be a string.')
#    1590 if isinstance(params['expression'], encodable.Encodable):
# -> 1591   params['expression'] = serializer.encode(
#    1592       params['expression'], for_cloud_api=True)
#    1593 num_retries = MAX_RETRIES if request_id else 0
#    1594 return _execute_cloud_call(
#    1595     export_endpoint(project=_get_projects_path(), body=params),
#    1596     num_retries=num_retries)
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:296, in encode(obj, is_compound, for_cloud_api, unbound_name)
#     280 """Serialize an object to a JSON-compatible structure for API calls.
#     281
#     282 Args:
#    (...)
#     292   A JSON-compatible structure representing the input.
#     293 """
#     294 serializer = Serializer(
#     295     is_compound, for_cloud_api=for_cloud_api, unbound_name=unbound_name)
# --> 296 return serializer._encode(obj)
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:79, in Serializer._encode(self, obj)
#      70 """Encodes a top level object to be executed server-side.
#      71
#      72 Args:
#    (...)
#      76   An encoded object ready for JSON serialization.
#      77 """
#      78 if self._for_cloud_api:
# ---> 79   return self._encode_for_cloud_api(obj)
#      80 value = self._encode_value(obj)
#      81 if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:97, in Serializer._encode_for_cloud_api(self, obj)
#      95 def _encode_for_cloud_api(self, obj):
#      96   """Encodes an object as an Expression or quasi-Expression."""
# ---> 97   value = self._encode_cloud_object(obj)
#      98   if self._is_compound:
#      99     # Wrap the scopes and final value into an Expression.
#     100     value = _ExpressionOptimizer(value, self._scope).optimize()
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (2 times), ComputedObject.encode_cloud_value at line 150 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/dictionary.py:74, in Dictionary.encode_cloud_value(self, opt_encoder)
#      72   return {'valueReference': opt_encoder(self._dictionary)}
#      73 else:
# ---> 74   return super(Dictionary, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/dictionary.py:74, in Dictionary.encode_cloud_value(self, opt_encoder)
#      72   return {'valueReference': opt_encoder(self._dictionary)}
#      73 else:
# ---> 74   return super(Dictionary, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/dictionary.py:72, in Dictionary.encode_cloud_value(self, opt_encoder)
#      70 def encode_cloud_value(self, opt_encoder=None):
#      71   if self._dictionary is not None:
# ---> 72     return {'valueReference': opt_encoder(self._dictionary)}
#      73   else:
#      74     return super(Dictionary, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:246, in Serializer._encode_cloud_object(self, obj)
#     236 elif isinstance(obj, dict):
#     237   # Dictionary are encoded recursively and wrapped in a type specifier.
#     238   # We iterate through the entries in a deterministic order, not because it
#    (...)
#     241   # ordering, the encoding process may produce one of multiple different
#     242   # (albeit equivalent) representations.
#     243   if self._is_compound:
#     244     result = {
#     245         'dictionaryValue': {
# --> 246             'values': {
#     247                 key: {
#     248                     'valueReference': self._encode_cloud_object(obj[key])
#     249                 } for key in sorted(obj)
#     250             }
#     251         }
#     252     }
#     253   else:
#     254     result = {
#     255         'dictionaryValue': {
#     256             'values': {
#    (...)
#     260         }
#     261     }
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:248, in <dictcomp>(.0)
#     236 elif isinstance(obj, dict):
#     237   # Dictionary are encoded recursively and wrapped in a type specifier.
#     238   # We iterate through the entries in a deterministic order, not because it
#    (...)
#     241   # ordering, the encoding process may produce one of multiple different
#     242   # (albeit equivalent) representations.
#     243   if self._is_compound:
#     244     result = {
#     245         'dictionaryValue': {
#     246             'values': {
#     247                 key: {
# --> 248                     'valueReference': self._encode_cloud_object(obj[key])
#     249                 } for key in sorted(obj)
#     250             }
#     251         }
#     252     }
#     253   else:
#     254     result = {
#     255         'dictionaryValue': {
#     256             'values': {
#    (...)
#     260         }
#     261     }
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/ee_list.py:74, in List.encode_cloud_value(self, opt_encoder)
#      72   return {'valueReference': opt_encoder(self._list)}
#      73 else:
# ---> 74   return super(List, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/ee_number.py:74, in Number.encode_cloud_value(self, opt_encoder)
#      72   return _cloud_api_utils.encode_number_as_cloud_value(self._number)
#      73 else:
# ---> 74   return super(Number, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/ee_number.py:74, in Number.encode_cloud_value(self, opt_encoder)
#      72   return _cloud_api_utils.encode_number_as_cloud_value(self._number)
#      73 else:
# ---> 74   return super(Number, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/ee_list.py:74, in List.encode_cloud_value(self, opt_encoder)
#      72   return {'valueReference': opt_encoder(self._list)}
#      73 else:
# ---> 74   return super(List, self).encode_cloud_value(opt_encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (1 times), ComputedObject.encode_cloud_value at line 150 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/ee_list.py:74, in List.encode_cloud_value(self, opt_encoder)
#      72   return {'valueReference': opt_encoder(self._list)}
#      73 else:
# ---> 74   return super(List, self).encode_cloud_value(opt_encoder)
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (2 times), ComputedObject.encode_cloud_value at line 150 (2 times), List.encode_cloud_value at line 74 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/customfunction.py:63, in CustomFunction.encode_cloud_value(self, encoder)
#      59 def encode_cloud_value(self, encoder):
#      60   return {
#      61       'functionDefinitionValue': {
#      62           'argumentNames': [x['name'] for x in self._signature['args']],
# ---> 63           'body': encoder(self._body)
#      64       }
#      65   }
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (2 times), List.encode_cloud_value at line 74 (1 times), ComputedObject.encode_cloud_value at line 150 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/customfunction.py:63, in CustomFunction.encode_cloud_value(self, encoder)
#      59 def encode_cloud_value(self, encoder):
#      60   return {
#      61       'functionDefinitionValue': {
#      62           'argumentNames': [x['name'] for x in self._signature['args']],
# ---> 63           'body': encoder(self._body)
#      64       }
#      65   }
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (4 times), ComputedObject.encode_cloud_value at line 150 (3 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/ee_list.py:74, in List.encode_cloud_value(self, opt_encoder)
#      72   return {'valueReference': opt_encoder(self._list)}
#      73 else:
# ---> 74   return super(List, self).encode_cloud_value(opt_encoder)
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (4 times), ComputedObject.encode_cloud_value at line 150 (3 times), CustomFunction.encode_cloud_value at line 63 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/customfunction.py:63, in CustomFunction.encode_cloud_value(self, encoder)
#      59 def encode_cloud_value(self, encoder):
#      60   return {
#      61       'functionDefinitionValue': {
#      62           'argumentNames': [x['name'] for x in self._signature['args']],
# ---> 63           'body': encoder(self._body)
#      64       }
#      65   }
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (1 times)]
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/geometry.py:588, in Geometry.encode_cloud_value(self, encoder)
#     586 """Returns a server-side invocation of the appropriate constructor."""
#     587 if not getattr(self, '_type', None):
# --> 588   return super(Geometry, self).encode_cloud_value(encoder)
#     590 return self._computed_equivalent.encode_cloud_value(encoder)
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/venv310/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/venv310/lib/python3.10/site-packages/ee/computedobject.py:135, in ComputedObject.encode_cloud_value(self, encoder)
#     128     ref = encoder.__self__.unbound_name
#     129   if ref is None:
#     130     # We are trying to call getInfo() or make some other server call inside
#     131     # a function passed to collection.map() or .iterate(), and the call uses
#     132     # one of the function arguments. The argument will be unbound outside of
#     133     # the map operation and cannot be evaluated. See the Count Functions
#     134     # case in customfunction.py for details on the unbound_name mechanism.
# --> 135     raise ee_exception.EEException(
#     136         'A mapped function\'s arguments cannot be used in client-side operations'
#     137     )
#     138   return {'argumentReference': ref}
#     139 else:
#
# EEException: A mapped function's arguments cannot be used in client-side operations
